# %% [markdown]
# # Wifi fingerprinting location

# %% [markdown]
# ## Exploring the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import plotly.express as px

# %%
trainset = pd.read_csv("C:/Users/edison/Documents/Ubiqum/Data Analytics Course/Module_III_Wifi/data/trainingData.csv", header = 0)

# %%
trainset.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
trainset.describe()
# Out:
#              WAP001        WAP002   WAP003   WAP004        WAP005  \
# count  19937.000000  19937.000000  19937.0  19937.0  19937.000000
# mean      99.823644     99.820936    100.0    100.0     99.613733
# std        5.866842      5.798156      0.0      0.0      8.615657
# min      -97.000000    -90.000000    100.0    100.0    -97.000000
# 25%      100.000000    100.000000    100.0    100.0    100.000000
# 50%      100.000000    100.000000    100.0    100.0    100.000000
# 75%      100.000000    100.000000    100.0    100.0    100.000000
# max      100.000000    100.000000    100.0    100.0    100.000000
#
#              WAP006        WAP007        WAP008        WAP009        WAP010  \
# count  19937.000000  19937.000000  19937.000000  19937.000000  19937.000000
# mean      97.130461     94.733661     93.820234     94.693936     99.163766
# std       22.931890     30.541335     33.010404     30.305084     12.634045
# ...

# %%
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19937 entries, 0 to 19936
# Columns: 529 entries, WAP001 to TIMESTAMP
# dtypes: float64(2), int64(527)
# memory usage: 80.5 MB

# %% [markdown]
# ### Histogram

# %%
trainset.dtypes.head()
# Out:
# WAP001    int64
# WAP002    int64
# WAP003    int64
# WAP004    int64
# WAP005    int64
# dtype: object

# %%
header = trainset.dtypes.index

# %%
print(header)
# Out:
# Index(['WAP001', 'WAP002', 'WAP003', 'WAP004', 'WAP005', 'WAP006', 'WAP007',
#        'WAP008', 'WAP009', 'WAP010',
#        ...
#        'WAP520', 'LONGITUDE', 'LATITUDE', 'FLOOR', 'BUILDINGID', 'SPACEID',
#        'RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'],
#       dtype='object', length=529)

# %%
plt.hist(trainset["WAP102"], bins = 100)
plt.show()

# %% [markdown]
# ### Sub-setting

# %%
train_small = trainset.loc[trainset["WAP102"] < 100, ["WAP102"]]

# %%
train_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 812 to 19325
# Data columns (total 1 columns):
# WAP102    847 non-null int64
# dtypes: int64(1)
# memory usage: 13.2 KB

# %%
train_small.describe()
# Out:
#            WAP102
# count  847.000000
# mean   -76.113341
# std     11.461062
# min    -98.000000
# 25%    -85.000000
# 50%    -79.000000
# 75%    -66.000000
# max    -43.000000

# %%
train_small.head()
# Out:
#       WAP102
# 812      -92
# 920      -92
# 3269     -70
# 3271     -54
# 3274     -56

# %%
plt.hist(train_small["WAP102"], bins= 10)
plt.show()

# %% [markdown]
# ## Transforming the WAP variables to 10^x

# %%
test = trainset.WAP102

# %%
test = pd.DataFrame(test)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19937 entries, 0 to 19936
# Data columns (total 1 columns):
# WAP102    19937 non-null int64
# dtypes: int64(1)
# memory usage: 155.8 KB

# %%
bla = pd.DataFrame({"col": [1,-2,3]})
bla["col"] = bla.col.apply(float)
bla["potencia"] = 10 ** bla["col"]
#print(potencia)
print(bla)
# Out:
#    col  potencia
# 0  1.0     10.00
# 1 -2.0      0.01
# 2  3.0   1000.00

# %%
test["WAP102"] = test.WAP102.apply(float)
test["exp_10"] = 10 ** test["WAP102"]
print(test.head())
# Out:
#    WAP102         exp_10
# 0   100.0  1.000000e+100
# 1   100.0  1.000000e+100
# 2   100.0  1.000000e+100
# 3   100.0  1.000000e+100
# 4   100.0  1.000000e+100

# %% [markdown]
# ### Replacing 1e+100 with zeros

# %%
test.loc[test["WAP102"] == 100, ["exp_10"]] = 0
print(test.head())
# Out:
#    WAP102  exp_10
# 0   100.0     0.0
# 1   100.0     0.0
# 2   100.0     0.0
# 3   100.0     0.0
# 4   100.0     0.0

# %%
print(test.loc[test["exp_10"] != 0,]["exp_10"].head())
# Out:
# 812     1.000000e-92
# 920     1.000000e-92
# 3269    1.000000e-70
# 3271    1.000000e-54
# 3274    1.000000e-56
# Name: exp_10, dtype: float64

# %% [markdown]
# ##

# %% [markdown]
# ### Histogram

# %%
plt.hist(test.loc[test["exp_10"] > 0,]["exp_10"], bins = 10)
plt.show()

# %%
plt.hist(test["exp_10"])
plt.show()

# %% [markdown]
# ## Exploring other variables of dataset

# %%
hist_userid = px.histogram(trainset, "PHONEID", nbins = 25)
hist_userid.show()
# Out:
# <div>
#
#
#             <div id="6969aa57-8a27-4cbf-b1af-a2ef0a4652f0" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6969aa57-8a27-4cbf-b1af-a2ef0a4652f0")) {
#                     Plotly.newPlot(
#                         '6969aa57-8a27-4cbf-b1af-a2ef0a4652f0',
# ...

# %%
hist_long = px.histogram(trainset, "LONGITUDE", nbins = 933)
hist_long.show()
# Out:
# <div>
#
#
#             <div id="6929471e-15b1-4772-81c7-027379f6822e" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6929471e-15b1-4772-81c7-027379f6822e")) {
#                     Plotly.newPlot(
#                         '6929471e-15b1-4772-81c7-027379f6822e',
# ...

# %%
trainset.loc[(trainset["LONGITUDE"] > -7541.2644) & (trainset["LONGITUDE"] < -7541.2642), :]
# Out:
#       WAP001  WAP002  WAP005  WAP006  WAP007  WAP008  WAP009  WAP010  WAP011  \
# 0       -200    -200    -200    -200    -200    -200    -200    -200    -200
# 112     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 219     -200    -200    -200    -200    -200     -97    -200    -200    -200
# 327     -200    -200    -200    -200    -200     -97    -200    -200    -200
# 442     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 546     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 655     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 766     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 880     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 986     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 1314    -200    -200    -200    -200    -200    -200    -200    -200    -200
# ...

# %%
trainset.head()
# Out:
#    WAP001  WAP002  WAP005  WAP006  WAP007  WAP008  WAP009  WAP010  WAP011  \
# 0    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 1    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 2    -200    -200    -200    -200    -200     -97    -200    -200    -200
# 3    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 4    -200    -200    -200    -200    -200    -200    -200    -200    -200
#
#    WAP012  ...  WAP519  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0    -200  ...    -200 -7541.2643  4.864921e+06      2           1      106
# 1    -200  ...    -200 -7536.6212  4.864934e+06      2           1      106
# 2    -200  ...    -200 -7519.1524  4.864950e+06      2           1      103
# 3    -200  ...    -200 -7524.5704  4.864934e+06      2           1      102
# 4    -200  ...    -200 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# # Removing WAPs with only 100

# %%
trainset.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
trainset.describe()
# Out:
#              WAP001        WAP002   WAP003   WAP004        WAP005  \
# count  19937.000000  19937.000000  19937.0  19937.0  19937.000000
# mean      99.823644     99.820936    100.0    100.0     99.613733
# std        5.866842      5.798156      0.0      0.0      8.615657
# min      -97.000000    -90.000000    100.0    100.0    -97.000000
# 25%      100.000000    100.000000    100.0    100.0    100.000000
# 50%      100.000000    100.000000    100.0    100.0    100.000000
# 75%      100.000000    100.000000    100.0    100.0    100.000000
# max      100.000000    100.000000    100.0    100.0    100.000000
#
#              WAP006        WAP007        WAP008        WAP009        WAP010  \
# count  19937.000000  19937.000000  19937.000000  19937.000000  19937.000000
# mean      97.130461     94.733661     93.820234     94.693936     99.163766
# std       22.931890     30.541335     33.010404     30.305084     12.634045
# ...

# %%
trainset = trainset.loc[:, (trainset.min() != 100)]

# %%
print(trainset.head())
# Out:
#    WAP001  WAP002  WAP005  WAP006  WAP007  WAP008  WAP009  WAP010  WAP011  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     -97     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP012  ...  WAP519  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %% [markdown]
# ### Replacing 100 with (-200)

# %%
trainset.min()[:465].min()
# Out:
# -104.0

# %%
temp = trainset.iloc[:,:465].replace(100, -200)

# %%
trainset.head()
# Out:
#    WAP001  WAP002  WAP005  WAP006  WAP007  WAP008  WAP009  WAP010  WAP011  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     -97     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP012  ...  WAP519  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
temp["LONGITUDE"] = trainset.LONGITUDE

# %%
temp["LATITUDE"] = trainset.LATITUDE

# %%
temp["FLOOR"] = trainset.FLOOR

# %%
temp["BUILDINGID"] = trainset.BUILDINGID

# %%
temp["SPACEID"] = trainset.SPACEID

# %%
temp["RELATIVEPOSITION"] = trainset.RELATIVEPOSITION

# %%
temp["USERID"] = trainset.USERID

# %%
temp["PHONEID"] = trainset.PHONEID

# %%
temp["TIMESTAMP"] = trainset.TIMESTAMP

# %%
trainset = temp[:]
trainset.head()
# Out:
#    WAP001  WAP002  WAP005  WAP006  WAP007  WAP008  WAP009  WAP010  WAP011  \
# 0    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 1    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 2    -200    -200    -200    -200    -200     -97    -200    -200    -200
# 3    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 4    -200    -200    -200    -200    -200    -200    -200    -200    -200
#
#    WAP012  ...  WAP519  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0    -200  ...    -200 -7541.2643  4.864921e+06      2           1      106
# 1    -200  ...    -200 -7536.6212  4.864934e+06      2           1      106
# 2    -200  ...    -200 -7519.1524  4.864950e+06      2           1      103
# 3    -200  ...    -200 -7524.5704  4.864934e+06      2           1      102
# 4    -200  ...    -200 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
trainset.max()
# Out:
# WAP001             -9.300000e+01
# WAP002             -8.600000e+01
# WAP005             -8.900000e+01
# WAP006             -5.800000e+01
# WAP007             -4.700000e+01
# WAP008             -6.100000e+01
# WAP009             -5.000000e+01
# WAP010             -8.400000e+01
# WAP011             -3.000000e+00
# WAP012              0.000000e+00
# WAP013             -4.000000e+01
# WAP014             -4.000000e+01
# WAP015             -6.900000e+01
# WAP016             -6.900000e+01
# WAP017             -8.400000e+01
# WAP018             -7.600000e+01
# WAP019             -5.100000e+01
# WAP020             -5.000000e+01
# WAP021             -9.000000e+01
# WAP022             -9.000000e+01
# WAP023             -4.000000e+01
# WAP024             -4.000000e+01
# WAP025             -4.600000e+01
# WAP026             -4.500000e+01
# WAP027             -4.400000e+01
# WAP028             -4.300000e+01
# WAP029             -3.100000e+01
# WAP030             -3.100000e+01
# ...

# %% [markdown]
# ### Plotting RSSI max

# %%
maxrssi_plot = px.scatter(y = trainset.max()[:465])
maxrssi_plot.show()
# Out:
# <div>
#
#
#             <div id="4d94d1c0-ff6e-465e-9a8a-2c45347481da" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d94d1c0-ff6e-465e-9a8a-2c45347481da")) {
#                     Plotly.newPlot(
#                         '4d94d1c0-ff6e-465e-9a8a-2c45347481da',
# ...

# %%
maxrssi = trainset.max()[:465]

# %%
plt.boxplot(maxrssi, 0, 'gD')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c488d20c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c488d20f28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c488d20828>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c488d059b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c488d05cf8>],
#  'means': []}

# %%
trainset.max().head()
# Out:
# WAP001   -93.0
# WAP002   -86.0
# WAP005   -89.0
# WAP006   -58.0
# WAP007   -47.0
# dtype: float64

# %% [markdown]
# ### Scatter plot of some WAPs

# %%
x = trainset["WAP500"]
y = trainset["LONGITUDE"]

# %%
plt.scatter(y, x)
plt.show()

# %% [markdown]
# ### SUbsetting per USERID

# %%
coord_plot = px.scatter(trainset, x = "LONGITUDE", y = "LATITUDE", color = "PHONEID")
coord_plot.show()
# Out:
# <div>
#
#
#             <div id="43381ce7-825b-49e7-a8c8-97b31b85be59" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43381ce7-825b-49e7-a8c8-97b31b85be59")) {
#                     Plotly.newPlot(
#                         '43381ce7-825b-49e7-a8c8-97b31b85be59',
# ...

# %%
lat_uni = trainset.LATITUDE.unique()

# %%
trainset.loc[trainset["LATITUDE"] == lat_uni[102], :]
# Out:
#       WAP001  WAP002  WAP005  WAP006  WAP007  WAP008  WAP009  WAP010  WAP011  \
# 105     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 209     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 319     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 431     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 539     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 646     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 760     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 869     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 978     -200    -200    -200    -200    -200    -200    -200    -200    -200
# 1087    -200    -200    -200    -200    -200    -200    -200    -200    -200
# 2301    -200    -200    -200    -200    -200    -200    -200    -200    -200
# ...

# %% [markdown]
# ### Printing the pre-processed dataset

# %%
export_trainset = trainset.to_csv (r'C:\Users\edison\Documents\Ubiqum\Data Analytics Course\Module_III_Wifi\Data\train_clean.csv', index = None, header=True)

# %% [markdown]
# ## Explore validation csv

# %%
validation = pd.read_csv("C:/Users/edison/Documents/Ubiqum/Data Analytics Course/Module_III_Wifi/data/validationData.csv", header = 0)

# %%
validation.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7515.916799  4.864890e+06      1           1        0
# 1     100  ...     100 -7383.867221  4.864840e+06      4           2        0
# 2     100  ...     100 -7374.302080  4.864847e+06      4           2        0
# 3     100  ...     100 -7365.824883  4.864843e+06      4           2        0
# 4     100  ...     100 -7641.499303  4.864922e+06      2           0        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
validation.describe()
# Out:
#             WAP001  WAP002       WAP003       WAP004  WAP005  WAP006  WAP007  \
# count  1111.000000  1111.0  1111.000000  1111.000000  1111.0  1111.0  1111.0
# mean     98.627363   100.0    99.665167    99.665167   100.0   100.0   100.0
# std      16.127245     0.0     7.888265     7.888607     0.0     0.0     0.0
# min     -94.000000   100.0   -87.000000   -88.000000   100.0   100.0   100.0
# 25%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 50%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 75%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# max     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
#
#             WAP008       WAP009       WAP010  ...       WAP520    LONGITUDE  \
# count  1111.000000  1111.000000  1111.000000  ...  1111.000000  1111.000000
# mean     94.297030    90.655266    98.811881  ...    99.843384 -7529.197448
# ...

# %%
validation.PHONEID.unique()
# Out:
# array([ 0, 13,  2, 12, 20, 21,  4,  9, 15,  5, 14], dtype=int64)

# %%
trainset.PHONEID.unique()
# Out:
# array([23, 13, 16, 18,  3, 19,  6,  1, 14,  8, 24, 17,  7, 11, 22, 10],
#       dtype=int64)
